# %%
from PIL import Image
from torchvision.utils import save_image

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load model
G_AB = Generator()  # your generator class
G_AB.load_state_dict(torch.load(r"G_A2B_trained.pth", map_location=device))
G_AB.to(device)
G_AB.eval()

# Load and preprocess user image
input_image = Image.open("abhi.jpg").convert("RGB")
input_tensor = transform(input_image).unsqueeze(0).to(device)

# Generate Ghibli-style image
with torch.no_grad():
    fake_B = G_AB(input_tensor)

# Denormalize and save
fake_B = (fake_B + 1) / 2
save_image(fake_B.cpu(), "ghibli_output11.png")

print("🎨 Ghibli-style image saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from PIL import Image
# ----> 2 from torchvision.utils import save_image
#       4 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#       6 # Load model
#
# ModuleNotFoundError: No module named 'torchvision'
